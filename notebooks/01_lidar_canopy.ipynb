# %% [markdown]
# # LiDAR canopy analysis
# Synthetic point-cloud demonstration.

# %%
from src.data_generation import generate_lidar
from src.lidar_metrics import canopy_metrics
df=generate_lidar()
canopy_metrics(df)
